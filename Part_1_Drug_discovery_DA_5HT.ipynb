# %% [markdown]
# <a href="https://colab.research.google.com/github/KarimeZeraik/QSAR-and-ML/blob/main/QSAR_Trypanosoma_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PROJECT:** Integration of machine learning, QSAR, and polypharmacology for multitarget drug discovery in neuropsychiatric disorders: Prediction of serotonergic and dopaminergic receptor inhibitors
#
# MSc. Caroline Mensor Folchini (UFPR)
#
# ***Code by Alexandre de F. Cobre*** [Github](https://github.com/AlexandreCOBRE/code)

# %% [markdown]
# # Performing the necessary installations/uninstallations:

# %%
# !pip install fastapi kaleido python-multipart uvicorn
# !pip install chembl_webresource_client
# Out:
# Requirement already satisfied: fastapi in /usr/local/lib/python3.12/dist-packages (0.116.1)
# Collecting kaleido
#   Downloading kaleido-1.1.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (0.0.20)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (0.35.0)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (0.47.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from fastapi) (2.11.7)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi) (4.15.0)
# Collecting choreographer>=1.0.10 (from kaleido)
#   Downloading choreographer-1.1.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting logistro>=1.0.8 (from kaleido)
#   Downloading logistro-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.12/dist-packages (from kaleido) (3.11.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaleido) (25.0)
# Collecting pytest-timeout>=2.4.0 (from kaleido)
#   Downloading pytest_timeout-2.4.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (8.2.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.12/dist-packages (from choreographer>=1.0.10->kaleido) (3.20.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.4.1)
# Requirement already satisfied: pytest>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from pytest-timeout>=2.4.0->kaleido) (8.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido) (2.19.2)
# Downloading kaleido-1.1.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.3/66.3 kB 3.7 MB/s eta 0:00:00
# Downloading choreographer-1.1.1-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 kB 4.0 MB/s eta 0:00:00
# Downloading logistro-1.1.0-py3-none-any.whl (7.9 kB)
# Downloading pytest_timeout-2.4.0-py3-none-any.whl (14 kB)
# Installing collected packages: logistro, pytest-timeout, choreographer, kaleido
# Successfully installed choreographer-1.1.1 kaleido-1.1.0 logistro-1.1.0 pytest-timeout-2.4.0
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2025.8.3)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.3.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.2.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.4.0)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 3.1 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.4 MB/s eta 0:00:00
# Downloading cattrs-25.2.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 6.0 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.2.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %% [markdown]
# # Importing necessary libraries:

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# #**DATASET SELECTION:**
#
# ChEMBL database (https://www.ebi.ac.uk/chembl/).

# %% [markdown]
# ### Searching for target datasets

# %%
alvo = new_client.target
pesquisa_alvo = alvo.search('Serotonin')
ds = pd.DataFrame.from_dict(pesquisa_alvo)
ds
# Out:
#    cross_references           organism  \
# 0                []         Ovis aries
# 1                []  Rattus norvegicus
# 2                []       Homo sapiens
# 3                []  Rattus norvegicus
# 4                []       Mus musculus
# ..              ...                ...
# 93               []       Mus musculus
# 94               []  Rattus norvegicus
# 95               []       Homo sapiens
# 96               []         Bos taurus
# 97               []  Rattus norvegicus
#
#                                             pref_name  score  \
# 0                       Serotonin N-acetyltransferase   14.0
# 1                       Serotonin N-acetyltransferase   14.0
# 2              Sodium-dependent serotonin transporter   12.0
# 3              Sodium-dependent serotonin transporter   12.0
# 4              Sodium-dependent serotonin transporter   12.0
# ..                                                ...    ...
# 93                    5-hydroxytryptamine receptor 2C    7.0
# 94                    5-hydroxytryptamine receptor 2C    7.0
# 95                              Monoamine transporter    7.0
# 96                    5-hydroxytryptamine 1D receptor    7.0
# 97  Serotonin 1a (5-HT1a) receptor/Adrenergic rece...    6.0
#
#     species_group_flag target_chembl_id  \
# 0                False       CHEMBL5452
# 1                False    CHEMBL1075242
# 2                False        CHEMBL228
# 3                False        CHEMBL313
# 4                False       CHEMBL4642
# ..                 ...              ...
# 93               False       CHEMBL3006
# 94               False        CHEMBL324
# 95               False    CHEMBL2363064
# 96               False    CHEMBL3638336
# 97               False    CHEMBL2097171
#
#                                     target_components        target_type  \
# 0   [{'accession': 'Q29495', 'component_descriptio...     SINGLE PROTEIN
# 1   [{'accession': 'Q64666', 'component_descriptio...     SINGLE PROTEIN
# 2   [{'accession': 'P31645', 'component_descriptio...     SINGLE PROTEIN
# 3   [{'accession': 'P31652', 'component_descriptio...     SINGLE PROTEIN
# 4   [{'accession': 'Q60857', 'component_descriptio...     SINGLE PROTEIN
# ..                                                ...                ...
# 93  [{'accession': 'P34968', 'component_descriptio...     SINGLE PROTEIN
# 94  [{'accession': 'P08909', 'component_descriptio...     SINGLE PROTEIN
# 95  [{'accession': 'P31645', 'component_descriptio...     PROTEIN FAMILY
# 96  [{'accession': 'Q8MI13', 'component_descriptio...     SINGLE PROTEIN
# 97  [{'accession': 'P15823', 'component_descriptio...  SELECTIVITY GROUP
#
#     tax_id
# 0     9940
# 1    10116
# 2     9606
# 3    10116
# 4    10090
# ..     ...
# 93   10090
# 94   10116
# 95    9606
# 96    9913
# 97   10116
#
# [98 rows x 9 columns]

# %% [markdown]
# ### Searching the dataset for a specific target:

# %%
# Listing all possible targets ("alvos") for visualization
lista_alvos = ds['pref_name'].tolist()
print(lista_alvos)
# Out:
# ['Serotonin N-acetyltransferase', 'Serotonin N-acetyltransferase', 'Sodium-dependent serotonin transporter', 'Sodium-dependent serotonin transporter', 'Sodium-dependent serotonin transporter', 'Sodium-dependent serotonin transporter', 'Monoamine transporters; Norepinephrine & serotonin', '5-hydroxytryptamine receptor 1D', '5-hydroxytryptamine receptor 1B', '5-hydroxytryptamine receptor 2B', '5-hydroxytryptamine receptor 1B', 'Serotonin 3 (5-HT3) receptor', 'Serotonin (5-HT) receptor', 'Serotonin 3 (5-HT3) receptor', 'Serotonin 1 (5-HT1) receptor', 'Serotonin 1 receptors; 5-HT1B & 5-HT1D', 'Serotonin (5-HT) receptor', 'Serotonin 3 (5-HT3) receptor', 'Serotonin 3 receptor (5HT3)', 'Serotonin receptor 2a and 2b (5HT2A and 5HT2B)', '5-hydroxytryptamine receptor 3A/3E', '5-hydroxytryptamine receptor 3A/3C', '5-HT1B/5-HT1F', '5-HT1D/5-HT1F', 'Serotonin 1 (5-HT1) receptor', '5-hydroxytryptamine receptor 3A', '5-hydroxytryptamine receptor 3A', 'Serotonin 4 (5-HT4) receptor', '5-hydroxytryptamine receptor 3A', '5-hydroxytryptamine receptor 3A', 'Serotonin 2 (5-HT2) receptor', 'Serotonin 2 (5-HT2) receptor', 'Serotonin 2 (5-HT2) receptor', 'Dopamine D2 receptor/Serotonin 2 (5-HT2) receptor', 'Serotonin 1B/1D receptor', '5-hydroxytryptamine receptor', 'Alpha-1B adrenergic receptor', '5-HT1A/5-HT1F', '5-hydroxytryptamine receptor 1A', '5-hydroxytryptamine receptor 2A', '5-hydroxytryptamine receptor 4', '5-hydroxytryptamine receptor 2B', '5-hydroxytryptamine receptor 1F', '5-hydroxytryptamine receptor 2B', '5-hydroxytryptamine receptor 7', '5-hydroxytryptamine receptor 7', '5-hydroxytryptamine receptor 1A', '5-hydroxytryptamine receptor 1B', '5-hydroxytryptamine receptor 1D', '5-hydroxytryptamine receptor 1E', '5-hydroxytryptamine receptor 1F', '5-hydroxytryptamine receptor 2A', '5-hydroxytryptamine receptor 2A', '5-hydroxytryptamine receptor 4', '5-hydroxytryptamine receptor 4', '5-hydroxytryptamine receptor 5A', '5-hydroxytryptamine receptor 5A', '5-hydroxytryptamine receptor 5A', '5-hydroxytryptamine receptor 6', '5-hydroxytryptamine receptor 6', '5-hydroxytryptamine receptor 3B', '5-hydroxytryptamine receptor 3B', '5-hydroxytryptamine receptor 1A', '5-hydroxytryptamine receptor 7', '5-hydroxytryptamine receptor 2A', '5-hydroxytryptamine receptor 5B', '5-hydroxytryptamine receptor 2A', '5-hydroxytryptamine receptor 1B', '5-hydroxytryptamine receptor 1D', '5-hydroxytryptamine receptor 1D', '5-hydroxytryptamine receptor 4', '5-hydroxytryptamine receptor 7', '5-hydroxytryptamine receptor 6', '5-hydroxytryptamine receptor 2C', 'Monoamine transporters; serotonin & dopamine', 'Monoamine transporters; serotonin & dopamine', 'Serotonin 2 receptors; 5-HT2a & 5-HT2c', 'Dopamine D2 receptor/Serotonin 2 (5-HT2) receptor', 'Serotonin receptor (2b and 2c)', 'Serotonin and norepinephrine transporters (SERT/NET)', 'Serotonin receptor 2a and 2c (5HT2A and 5HT2C)', '5-hydroxytryptamine receptor 1D', '5-hydroxytryptamine receptor 1B', '5-hydroxytryptamine receptor 2A', '5-hydroxytryptamine receptor 1B', '5-hydroxytryptamine receptor 1B', '5-hydroxytryptamine receptor 1B', '5-hydroxytryptamine receptor 2C', '5-hydroxytryptamine receptor 2A', 'Dopamine D2 receptor and serotonin 1a receptor', 'Dopamine D2 receptor and serotonin 2a receptor', 'Dopamine D2 receptor and Serotonin 2a receptor (D2 and 5HT2a)', '5-hydroxytryptamine receptor 2A/Metabotropic glutamate receptor 2', '5-hydroxytryptamine receptor 2C', '5-hydroxytryptamine receptor 2C', 'Monoamine transporter', '5-hydroxytryptamine 1D receptor', 'Serotonin 1a (5-HT1a) receptor/Adrenergic receptor alpha-1']

# %%
# Defining the target to be searched
alvo = "Serotonin"

# Checking if any element in pref_name contains this target:
contains_alvo = ds['pref_name'].str.contains(alvo)

# Getting the indices of the rows with the defined target:
indices_com_alvo = ds[contains_alvo].index.tolist()

if contains_alvo.any():
    print(f"At least one element contains the term: {alvo}")
    print(f"Indices of the rows with the term'{alvo}': {indices_com_alvo}")
else:
    print(f"No element contains the term: {alvo}")
# Out:
# At least one element contains the term: Serotonin
# Indices of the rows with the term'Serotonin': [0, 1, 11, 12, 13, 14, 15, 16, 17, 18, 19, 24, 27, 30, 31, 32, 33, 34, 76, 77, 78, 79, 80, 91, 97]

# %% [markdown]
# ### Converting IC50 values to a standard concentration unit (molar - M) and generating a single dataframe:

# %%
# prompt: select rows from df['target_chembl_id']

ensaios = ds[ds['target_chembl_id'].isin(['CHEMBL224', 'CHEMBL3155', 'CHEMBL225', 'CHEMBL214'])]

# %%
indices_com_ensaio = ensaios.index
indices_com_ensaio
# Out:
# Index([38, 39, 45, 87], dtype='int64')

# %%
# Creating a list to store individual DataFrames

dfs = []




# Iterating over the different indices:

for i in indices_com_ensaio :

    df_nM_i = []

    df_uM_i = []

    df_mM_i = []

    df_M_i = []

    ds_selecionado_i = ds.target_chembl_id[i]




    # Filtering bioactive compounds with IC50 data, in nM units, for each index:

    atividade = new_client.activity

    resultado_nM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="nM")




    # Filtering bioactive compounds with IC50 data, in µM units, for each index:

    resultado_uM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="uM")




    # Filtering bioactive compounds with IC50 data, in mM units, for each index:

    resultado_mM = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="mM")




    # Filtering bioactive compounds with IC50 data, in M units, for each index:

    resultado_M = atividade.filter(target_chembl_id=ds_selecionado_i).filter(standard_type="IC50").filter(units="M")




    # Creating a DataFrame for each unit:

    df_nM_i = pd.DataFrame.from_dict(resultado_nM)

    df_uM_i = pd.DataFrame.from_dict(resultado_uM)

    df_mM_i = pd.DataFrame.from_dict(resultado_mM)

    df_M_i = pd.DataFrame.from_dict(resultado_M)




    # Converting each DataFrame to a standard unit (M):

    if not df_nM_i.empty and 'value' in df_nM_i:

        df_nM_i['value'] = df_nM_i['value'].astype(float)

        df_nM_i['value'] *= 1e-9

    else:

        pass




    if not df_uM_i.empty and 'value' in df_uM_i:

        df_uM_i['value'] = df_uM_i['value'].astype(float)

        df_uM_i['value'] *= 1e-6

    else:

        pass




    if not df_mM_i.empty and 'value' in df_mM_i:

        df_mM_i['value'] = df_mM_i['value'].astype(float)

        df_mM_i['value'] *= 1e-3

    else:

        pass




    if not df_M_i.empty and 'value' in df_M_i:

        df_M_i['value'] = df_M_i['value'].astype(float)

    else:

        pass




    # Adding the DataFrames to the list:

    dfs.append(df_nM_i)

    dfs.append(df_uM_i)

    dfs.append(df_mM_i)

    dfs.append(df_M_i)




# Concatenating the individual DataFrames into a single DataFrame:

df_assays = pd.concat(dfs, ignore_index=True)

df_assays['units'] = 'M'




# Displaying the final DataFrame:

display(df_assays)
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None   Not Determined
# 4                                                  None   Not Determined
# ...                                                 ...              ...
# 3592  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3593  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3594                                               None             None
# 3595                                               None             None
# 3596                                               None             None
#
#       activity_id                                activity_properties  \
# 0          221588                                                 []
# 1          431267                                                 []
# 2          431269                                                 []
# 3          437720                                                 []
# 4          437721                                                 []
# ...           ...                                                ...
# 3592     25986621  [{'comments': None, 'relation': '=', 'result_f...
# 3593     25986622  [{'comments': None, 'relation': '=', 'result_f...
# 3594     26298118                                                 []
# 3595     26298119                                                 []
# 3596      1098046                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL615582  Compound was evaluated for the binding affinit...
# 1       CHEMBL615748  Agonistic activity of compound towards 5-hydro...
# 2       CHEMBL615750  Agonistic activity of compound towards 5-hydro...
# 3       CHEMBL615749  Agonistic activity of compound towards 5-hydro...
# 4       CHEMBL616259  Forskolin stimulated cAMP assessment of agonis...
# ...              ...                                                ...
# 3592   CHEMBL5548750  Antagonist activity at recombinant human 5-HT2...
# 3593   CHEMBL5548750  Antagonist activity at recombinant human 5-HT2...
# 3594   CHEMBL5697018  Inhibition of human 5-HT2C by intracellular Ca...
# 3595   CHEMBL5697018  Inhibition of human 5-HT2C by intracellular Ca...
# 3596    CHEMBL620674  Ability to displace [3H]mesulergine from 5-hyd...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             F                    None                   None  BAO_0000190
# 2             F                    None                   None  BAO_0000190
# 3             F                    None                   None  BAO_0000190
# 4             F                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 3592          F                    None                   None  BAO_0000190
# 3593          F                    None                   None  BAO_0000190
# 3594          F                    None                   None  BAO_0000190
# 3595          F                    None                   None  BAO_0000190
# 3596          B                    None                   None  BAO_0000190
#
#       ... target_organism                 target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# 1     ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# 2     ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# 3     ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# 4     ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# ...   ...             ...                              ...           ...
# 3592  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
# 3593  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
# 3594  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
# 3595  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
# 3596  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
#
#      text_value  toid  type units    uo_units upper_value         value
# 0          None  None  IC50     M  UO_0000065        None  1.000000e-06
# 1          None  None  IC50     M  UO_0000065        None  3.600000e-08
# 2          None  None  IC50     M  UO_0000065        None  1.300000e-07
# 3          None  None  IC50     M  UO_0000065        None           NaN
# 4          None  None  IC50     M  UO_0000065        None           NaN
# ...         ...   ...   ...   ...         ...         ...           ...
# 3592       None  None  IC50     M  UO_0000065        None  2.950000e-06
# 3593       None  None  IC50     M  UO_0000065        None  5.530000e-06
# 3594       None  None  IC50     M  UO_0000065        None  4.000000e-05
# 3595       None  None  IC50     M  UO_0000065        None  4.000000e-05
# 3596       None  None  IC50     M  UO_0000065        None  3.400000e-06
#
# [3597 rows x 46 columns]

# %%
df_assays["value"].isnull().sum()
# Out:
# np.int64(19)

# %%
# Assuming your DataFrame is df_assays
df_assays.dropna(subset=['value'], inplace=True)

# %%
df_assays
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 13                                                 None             None
# 14                                                 None             None
# ...                                                 ...              ...
# 3592  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3593  {'action_type': 'ANTAGONIST', 'description': '...             None
# 3594                                               None             None
# 3595                                               None             None
# 3596                                               None             None
#
#       activity_id                                activity_properties  \
# 0          221588                                                 []
# 1          431267                                                 []
# 2          431269                                                 []
# 13         449757                                                 []
# 14         449759                                                 []
# ...           ...                                                ...
# 3592     25986621  [{'comments': None, 'relation': '=', 'result_f...
# 3593     25986622  [{'comments': None, 'relation': '=', 'result_f...
# 3594     26298118                                                 []
# 3595     26298119                                                 []
# 3596      1098046                                                 []
#
#      assay_chembl_id                                  assay_description  \
# 0       CHEMBL615582  Compound was evaluated for the binding affinit...
# 1       CHEMBL615748  Agonistic activity of compound towards 5-hydro...
# 2       CHEMBL615750  Agonistic activity of compound towards 5-hydro...
# 13      CHEMBL616260  Agonistic activity of compound towards 5-hydro...
# 14      CHEMBL615750  Agonistic activity of compound towards 5-hydro...
# ...              ...                                                ...
# 3592   CHEMBL5548750  Antagonist activity at recombinant human 5-HT2...
# 3593   CHEMBL5548750  Antagonist activity at recombinant human 5-HT2...
# 3594   CHEMBL5697018  Inhibition of human 5-HT2C by intracellular Ca...
# 3595   CHEMBL5697018  Inhibition of human 5-HT2C by intracellular Ca...
# 3596    CHEMBL620674  Ability to displace [3H]mesulergine from 5-hyd...
#
#      assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0             B                    None                   None  BAO_0000190
# 1             F                    None                   None  BAO_0000190
# 2             F                    None                   None  BAO_0000190
# 13            F                    None                   None  BAO_0000190
# 14            F                    None                   None  BAO_0000190
# ...         ...                     ...                    ...          ...
# 3592          F                    None                   None  BAO_0000190
# 3593          F                    None                   None  BAO_0000190
# 3594          F                    None                   None  BAO_0000190
# 3595          F                    None                   None  BAO_0000190
# 3596          B                    None                   None  BAO_0000190
#
#       ... target_organism                 target_pref_name target_tax_id  \
# 0     ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# 1     ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# 2     ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# 13    ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# 14    ...    Homo sapiens  5-hydroxytryptamine receptor 1A          9606
# ...   ...             ...                              ...           ...
# 3592  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
# 3593  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
# 3594  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
# 3595  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
# 3596  ...    Homo sapiens  5-hydroxytryptamine receptor 2C          9606
#
#      text_value  toid  type units    uo_units upper_value         value
# 0          None  None  IC50     M  UO_0000065        None  1.000000e-06
# 1          None  None  IC50     M  UO_0000065        None  3.600000e-08
# 2          None  None  IC50     M  UO_0000065        None  1.300000e-07
# 13         None  None  IC50     M  UO_0000065        None  2.500000e-08
# 14         None  None  IC50     M  UO_0000065        None  2.100000e-08
# ...         ...   ...   ...   ...         ...         ...           ...
# 3592       None  None  IC50     M  UO_0000065        None  2.950000e-06
# 3593       None  None  IC50     M  UO_0000065        None  5.530000e-06
# 3594       None  None  IC50     M  UO_0000065        None  4.000000e-05
# 3595       None  None  IC50     M  UO_0000065        None  4.000000e-05
# 3596       None  None  IC50     M  UO_0000065        None  3.400000e-06
#
# [3578 rows x 46 columns]

# %%
# Assigning the class of the compounds

classe_bioatividade = []
for i in df_assays.standard_value:
    if float(i) > 0.0010:
        classe_bioatividade.append("Inactive")
    elif float(i) <= 0.00010:
        classe_bioatividade.append("Active")
    else:
        classe_bioatividade.append("Intermediate")

# %%
# Visualizing bioactive compounds
df_assays.molecule_chembl_id
# Out:
# 0         CHEMBL26560
# 1        CHEMBL148860
# 2        CHEMBL148860
# 13       CHEMBL151266
# 14       CHEMBL151266
#             ...
# 3592    CHEMBL5594692
# 3593    CHEMBL5567330
# 3594    CHEMBL1232461
# 3595    CHEMBL2017291
# 3596      CHEMBL35226
# Name: molecule_chembl_id, Length: 3578, dtype: object

# %%
# Iterating over bioactive compounds
mol_cid = []
for i in df_assays.molecule_chembl_id:
    mol_cid.append(i)

# %%
# Printing the variable mol_cid
mol_cid
# Out:
# ['CHEMBL26560',
#  'CHEMBL148860',
#  'CHEMBL148860',
#  'CHEMBL151266',
#  'CHEMBL151266',
#  'CHEMBL146751',
#  'CHEMBL146751',
#  'CHEMBL355953',
#  'CHEMBL553331',
#  'CHEMBL305660',
#  'CHEMBL338611',
#  'CHEMBL359124',
#  'CHEMBL359124',
#  'CHEMBL153174',
#  'CHEMBL153174',
#  'CHEMBL39',
#  'CHEMBL39',
#  'CHEMBL39',
#  'CHEMBL39',
#  'CHEMBL155615',
#  'CHEMBL155615',
#  'CHEMBL284820',
#  'CHEMBL423045',
#  'CHEMBL423045',
#  'CHEMBL31115',
#  'CHEMBL135076',
#  'CHEMBL133455',
#  'CHEMBL133868',
#  'CHEMBL27173',
#  'CHEMBL39',
#  'CHEMBL275854',
#  'CHEMBL25800',
#  'CHEMBL131736',
#  'CHEMBL134519',
#  'CHEMBL412876',
#  'CHEMBL275008',
#  'CHEMBL267559',
#  'CHEMBL60318',
#  'CHEMBL293923',
#  'CHEMBL64878',
#  'CHEMBL60447',
#  'CHEMBL42',
#  'CHEMBL59741',
#  'CHEMBL60885',
#  'CHEMBL64610',
#  'CHEMBL292935',
#  'CHEMBL61869',
#  'CHEMBL64167',
#  'CHEMBL59637',
#  'CHEMBL61818',
#  'CHEMBL60047',
#  'CHEMBL418499',
#  'CHEMBL61819',
#  'CHEMBL64845',
#  'CHEMBL54',
#  'CHEMBL294730',
#  'CHEMBL304438',
#  'CHEMBL59823',
#  'CHEMBL116735',
#  'CHEMBL116463',
#  'CHEMBL326538',
#  'CHEMBL326263',
#  'CHEMBL159483',
#  'CHEMBL160070',
#  'CHEMBL325516',
#  'CHEMBL420965',
#  'CHEMBL325258',
#  'CHEMBL161780',
#  'CHEMBL115444',
#  'CHEMBL318604',
#  'CHEMBL318604',
#  'CHEMBL318738',
#  'CHEMBL105390',
#  'CHEMBL105390',
#  'CHEMBL104229',
#  'CHEMBL104229',
#  'CHEMBL104144',
#  'CHEMBL104144',
#  'CHEMBL442391',
#  'CHEMBL442391',
#  'CHEMBL322915',
#  'CHEMBL322915',
#  'CHEMBL421027',
#  'CHEMBL421027',
#  'CHEMBL340873',
#  'CHEMBL340873',
#  'CHEMBL340895',
#  'CHEMBL339490',
#  'CHEMBL339490',
#  'CHEMBL435612',
#  'CHEMBL39',
#  'CHEMBL124069',
#  'CHEMBL124069',
#  'CHEMBL330827',
#  'CHEMBL338520',
#  'CHEMBL338520',
#  'CHEMBL133939',
#  'CHEMBL339810',
#  'CHEMBL338482',
#  'CHEMBL338482',
#  'CHEMBL7257',
#  'CHEMBL137485',
#  'CHEMBL124638',
#  'CHEMBL313714',
#  'CHEMBL346389',
#  'CHEMBL371149',
#  'CHEMBL371149',
#  'CHEMBL435111',
#  'CHEMBL435111',
#  'CHEMBL372205',
#  'CHEMBL372205',
#  'CHEMBL193206',
#  'CHEMBL193206',
#  'CHEMBL537403',
#  'CHEMBL537403',
#  'CHEMBL56',
#  'CHEMBL54786',
#  'CHEMBL370110',
#  'CHEMBL198463',
#  'CHEMBL537403',
#  'CHEMBL213673',
#  'CHEMBL385353',
#  'CHEMBL379298',
#  'CHEMBL209784',
#  'CHEMBL213639',
#  'CHEMBL208605',
#  'CHEMBL210348',
#  'CHEMBL208774',
#  'CHEMBL208773',
#  'CHEMBL380095',
#  'CHEMBL209802',
#  'CHEMBL427051',
#  'CHEMBL211393',
#  'CHEMBL211363',
#  'CHEMBL220808',
#  'CHEMBL273041',
#  'CHEMBL259415',
#  'CHEMBL261102',
#  'CHEMBL261019',
#  'CHEMBL261434',
#  'CHEMBL259776',
#  'CHEMBL260907',
#  'CHEMBL259199',
#  'CHEMBL406221',
#  'CHEMBL410832',
#  'CHEMBL259732',
#  'CHEMBL22744',
#  'CHEMBL493625',
#  'CHEMBL495250',
#  'CHEMBL495212',
#  'CHEMBL497749',
#  'CHEMBL495678',
#  'CHEMBL493816',
#  'CHEMBL427518',
#  'CHEMBL488812',
#  'CHEMBL427411',
#  'CHEMBL457750',
#  'CHEMBL457751',
#  'CHEMBL537403',
#  'CHEMBL386288',
#  'CHEMBL211363',
#  'CHEMBL380095',
#  'CHEMBL208773',
#  'CHEMBL484572',
#  'CHEMBL484572',
#  'CHEMBL484580',
#  'CHEMBL484747',
#  'CHEMBL485433',
#  'CHEMBL485434',
#  'CHEMBL521303',
#  'CHEMBL483594',
#  'CHEMBL484947',
#  'CHEMBL484948',
#  'CHEMBL485385',
#  'CHEMBL519679',
#  'CHEMBL484540',
#  'CHEMBL484541',
#  'CHEMBL521341',
#  'CHEMBL208774',
#  'CHEMBL485228',
#  'CHEMBL485228',
#  'CHEMBL484581',
#  'CHEMBL483573',
#  'CHEMBL520661',
#  'CHEMBL521510',
#  'CHEMBL485624',
#  'CHEMBL485625',
#  'CHEMBL485625',
#  'CHEMBL485381',
#  'CHEMBL519514',
#  'CHEMBL484537',
#  'CHEMBL485397',
#  'CHEMBL485398',
#  'CHEMBL519325',
#  'CHEMBL485407',
#  'CHEMBL485407',
#  'CHEMBL485579',
#  'CHEMBL485579',
#  'CHEMBL456657',
#  'CHEMBL456657',
#  'CHEMBL483370',
#  'CHEMBL457570',
#  'CHEMBL475969',
#  'CHEMBL515307',
#  'CHEMBL476006',
#  'CHEMBL477650',
#  'CHEMBL56',
#  'CHEMBL516452',
#  'CHEMBL479952',
#  'CHEMBL519103',
#  'CHEMBL480699',
#  'CHEMBL480127',
#  'CHEMBL14460',
#  'CHEMBL551909',
#  'CHEMBL564148',
#  'CHEMBL551304',
#  'CHEMBL560170',
#  'CHEMBL551107',
#  'CHEMBL565234',
#  'CHEMBL550576',
#  'CHEMBL551105',
#  'CHEMBL559778',
#  'CHEMBL551964',
#  'CHEMBL550700',
#  'CHEMBL559579',
#  'CHEMBL550169',
#  'CHEMBL556474',
#  'CHEMBL562248',
#  'CHEMBL584554',
#  'CHEMBL21343',
#  'CHEMBL182150',
#  'CHEMBL605938',
#  'CHEMBL593889',
#  'CHEMBL605292',
#  'CHEMBL595301',
#  'CHEMBL595449',
#  'CHEMBL607419',
#  'CHEMBL607419',
#  'CHEMBL596297',
#  'CHEMBL596297',
#  'CHEMBL608728',
#  'CHEMBL609317',
#  'CHEMBL609611',
#  'CHEMBL431367',
#  'CHEMBL130327',
#  'CHEMBL1086626',
#  'CHEMBL1086754',
#  'CHEMBL1086756',
#  'CHEMBL1094558',
#  'CHEMBL1096476',
#  'CHEMBL1097181',
#  'CHEMBL1094872',
#  'CHEMBL1096155',
#  'CHEMBL1098483',
#  'CHEMBL1094556',
#  'CHEMBL1097484',
#  'CHEMBL31354',
#  'CHEMBL1096671',
#  'CHEMBL1096529',
#  'CHEMBL1098133',
#  'CHEMBL1098134',
#  'CHEMBL1096540',
#  'CHEMBL1094557',
#  'CHEMBL1096156',
#  'CHEMBL1096477',
#  'CHEMBL1096802',
#  'CHEMBL1096530',
#  'CHEMBL1210154',
#  'CHEMBL1221497',
#  'CHEMBL1222362',
#  'CHEMBL1221452',
#  'CHEMBL1222234',
#  'CHEMBL1222364',
#  'CHEMBL1221449',
#  'CHEMBL1222138',
#  'CHEMBL1222363',
#  'CHEMBL1222134',
#  'CHEMBL1275709',
#  'CHEMBL1275791',
#  'CHEMBL1277371',
#  'CHEMBL1278088',
#  'CHEMBL1277558',
#  'CHEMBL1278174',
#  'CHEMBL1276833',
#  'CHEMBL1277463',
#  'CHEMBL1277281',
#  'CHEMBL1276919',
#  'CHEMBL1277006',
#  'CHEMBL1277560',
#  'CHEMBL1277995',
#  'CHEMBL1277913',
#  'CHEMBL1277280',
#  'CHEMBL1276832',
#  'CHEMBL1277373',
#  'CHEMBL1277098',
#  'CHEMBL1277283',
#  'CHEMBL1277188',
#  'CHEMBL1277101',
#  'CHEMBL1276920',
#  'CHEMBL1277465',
#  'CHEMBL1277100',
#  'CHEMBL1277282',
#  'CHEMBL1277462',
#  'CHEMBL1276834',
#  'CHEMBL1277652',
#  'CHEMBL1277745',
#  'CHEMBL1277832',
#  'CHEMBL1277833',
#  'CHEMBL1278175',
#  'CHEMBL1278176',
#  'CHEMBL1276835',
#  'CHEMBL1276922',
#  'CHEMBL1277372',
#  'CHEMBL1277099',
#  'CHEMBL1277559',
#  'CHEMBL1277651',
#  'CHEMBL1277746',
#  'CHEMBL1277914',
#  'CHEMBL1277996',
#  'CHEMBL1278087',
#  'CHEMBL1276921',
#  'CHEMBL1277007',
#  'CHEMBL1277005',
#  'CHEMBL1277186',
#  'CHEMBL1277187',
#  'CHEMBL1277189',
#  'CHEMBL1277374',
#  'CHEMBL1277464',
#  'CHEMBL1642116',
#  'CHEMBL1642117',
#  'CHEMBL1642118',
#  'CHEMBL1642123',
#  'CHEMBL1642126',
#  'CHEMBL1642128',
#  'CHEMBL1774997',
#  'CHEMBL1774996',
#  'CHEMBL1774995',
#  'CHEMBL1774994',
#  'CHEMBL423361',
#  'CHEMBL1774993',
#  'CHEMBL1774992',
#  'CHEMBL1774991',
#  'CHEMBL1774990',
#  'CHEMBL31354',
#  'CHEMBL3216758',
#  'CHEMBL3216098',
#  'CHEMBL537403',
#  'CHEMBL1910138',
#  'CHEMBL1910139',
#  'CHEMBL1910140',
#  'CHEMBL1910141',
#  'CHEMBL423361',
#  'CHEMBL1910142',
#  'CHEMBL1910143',
#  'CHEMBL1910144',
#  'CHEMBL1910145',
#  'CHEMBL537403',
#  'CHEMBL2387229',
#  'CHEMBL2393244',
#  'CHEMBL2393245',
#  'CHEMBL2393246',
#  'CHEMBL2393243',
#  'CHEMBL56',
#  'CHEMBL19215',
#  'CHEMBL56',
#  'CHEMBL3092346',
#  'CHEMBL3092345',
#  'CHEMBL3092344',
#  'CHEMBL3092343',
#  'CHEMBL3092342',
#  'CHEMBL3092351',
#  'CHEMBL3092350',
#  'CHEMBL3092349',
#  'CHEMBL3092348',
#  'CHEMBL3092347',
#  'CHEMBL3286556',
#  'CHEMBL514874',
#  'CHEMBL514874',
#  'CHEMBL3797529',
#  'CHEMBL3899744',
#  'CHEMBL3946995',
#  'CHEMBL1256737',
#  'CHEMBL3705001',
#  'CHEMBL3656923',
#  'CHEMBL3705035',
#  'CHEMBL3913343',
#  'CHEMBL3897805',
#  'CHEMBL3986624',
#  'CHEMBL2057441',
#  'CHEMBL2057438',
#  'CHEMBL8618',
#  'CHEMBL4130132',
#  'CHEMBL4126092',
#  'CHEMBL4129173',
#  'CHEMBL4127564',
#  'CHEMBL4129293',
#  'CHEMBL4128053',
#  'CHEMBL4129562',
#  'CHEMBL4128926',
#  'CHEMBL4209888',
#  'CHEMBL4205526',
#  'CHEMBL4212812',
#  'CHEMBL4213352',
#  'CHEMBL4207653',
#  'CHEMBL4203310',
#  'CHEMBL8618',
#  'CHEMBL38288',
#  'CHEMBL4293999',
#  'CHEMBL31354',
#  'CHEMBL3421729',
#  'CHEMBL4591601',
#  'CHEMBL4465959',
#  'CHEMBL8618',
#  'CHEMBL4582321',
#  'CHEMBL364610',
#  'CHEMBL186655',
#  'CHEMBL360407',
#  'CHEMBL189709',
#  'CHEMBL188799',
#  'CHEMBL188798',
#  'CHEMBL439849',
#  'CHEMBL360390',
#  'CHEMBL4476621',
#  'CHEMBL56',
#  'CHEMBL4764679',
#  'CHEMBL31354',
#  'CHEMBL4867978',
#  'CHEMBL4851044',
#  'CHEMBL4870130',
#  'CHEMBL4867414',
#  'CHEMBL4864918',
#  'CHEMBL439849',
#  'CHEMBL304426',
#  'CHEMBL148860',
#  'CHEMBL31354',
#  'CHEMBL5505942',
#  'CHEMBL15245',
#  'CHEMBL1256737',
#  'CHEMBL3705001',
#  'CHEMBL3656923',
#  'CHEMBL3705035',
#  'CHEMBL3913343',
#  'CHEMBL3897805',
#  'CHEMBL3986624',
#  'CHEMBL2057441',
#  'CHEMBL2057438',
#  'CHEMBL6004129',
#  'CHEMBL5095172',
#  'CHEMBL6004129',
#  'CHEMBL5095172',
#  'CHEMBL5798159',
#  'CHEMBL5766436',
#  'CHEMBL5817624',
#  'CHEMBL6009219',
#  'CHEMBL5909593',
#  'CHEMBL5766304',
#  'CHEMBL6033750',
#  'CHEMBL5926623',
#  'CHEMBL5742873',
#  'CHEMBL5784881',
#  'CHEMBL6051413',
#  'CHEMBL6030256',
#  'CHEMBL5789899',
#  'CHEMBL6064944',
#  'CHEMBL6061458',
#  'CHEMBL5962159',
#  'CHEMBL5878087',
#  'CHEMBL5817080',
#  'CHEMBL5871654',
#  'CHEMBL5773895',
#  'CHEMBL5947240',
#  'CHEMBL5756186',
#  'CHEMBL6003636',
#  'CHEMBL5840994',
#  'CHEMBL5769381',
#  'CHEMBL5888905',
#  'CHEMBL6001722',
#  'CHEMBL5950738',
#  'CHEMBL5823916',
#  'CHEMBL5911465',
#  'CHEMBL5853768',
#  'CHEMBL5951076',
#  'CHEMBL5956985',
#  'CHEMBL5917824',
#  'CHEMBL6005497',
#  'CHEMBL6051037',
#  'CHEMBL6047196',
#  'CHEMBL5771610',
#  'CHEMBL49',
#  'CHEMBL27429',
#  'CHEMBL47419',
#  'CHEMBL46095',
#  'CHEMBL49586',
#  'CHEMBL47497',
#  'CHEMBL45853',
#  'CHEMBL49575',
#  'CHEMBL49950',
#  'CHEMBL296254',
#  'CHEMBL281720',
#  'CHEMBL49489',
#  'CHEMBL284092',
#  'CHEMBL47628',
#  'CHEMBL297099',
#  'CHEMBL44837',
#  'CHEMBL49432',
#  'CHEMBL46075',
#  'CHEMBL297306',
#  'CHEMBL297543',
#  'CHEMBL44992',
#  'CHEMBL299406',
#  'CHEMBL355149',
#  'CHEMBL350972',
#  'CHEMBL198949',
#  'CHEMBL372312',
#  'CHEMBL377498',
#  'CHEMBL202939',
#  'CHEMBL369997',
#  'CHEMBL204759',
#  'CHEMBL204254',
#  'CHEMBL203403',
#  'CHEMBL204490',
#  'CHEMBL379679',
#  'CHEMBL381127',
#  'CHEMBL379446',
#  'CHEMBL203563',
#  'CHEMBL202420',
#  'CHEMBL399203',
#  'CHEMBL250403',
#  'CHEMBL250699',
#  'CHEMBL506736',
#  'CHEMBL468176',
#  'CHEMBL566075',
#  'CHEMBL1092929',
#  'CHEMBL1089881',
#  'CHEMBL1092921',
#  'CHEMBL1088874',
#  'CHEMBL1093469',
#  'CHEMBL1092238',
#  'CHEMBL1093802',
#  'CHEMBL1089793',
#  'CHEMBL1082723',
#  'CHEMBL1829958',
#  'CHEMBL1829961',
#  'CHEMBL1829566',
#  'CHEMBL1829574',
#  'CHEMBL1829578',
#  'CHEMBL1829580',
#  'CHEMBL1829659',
#  'CHEMBL2322611',
#  'CHEMBL422931',
#  'CHEMBL3099716',
#  'CHEMBL3099899',
#  'CHEMBL3338677',
#  'CHEMBL4101902',
#  'CHEMBL4216860',
#  'CHEMBL4207529',
#  'CHEMBL4212435',
#  'CHEMBL4209942',
#  'CHEMBL4212246',
#  'CHEMBL4207355',
#  'CHEMBL4216246',
#  'CHEMBL4204576',
#  'CHEMBL4204036',
#  'CHEMBL266195',
#  'CHEMBL4459696',
#  'CHEMBL4542960',
#  'CHEMBL4458797',
#  'CHEMBL4452249',
#  'CHEMBL4475573',
#  'CHEMBL4454523',
#  'CHEMBL4466532',
#  'CHEMBL4587648',
#  'CHEMBL4527905',
#  'CHEMBL4545079',
#  'CHEMBL4440189',
#  'CHEMBL3648680',
#  'CHEMBL3648680',
#  'CHEMBL1910917',
#  'CHEMBL4534493',
#  'CHEMBL4588956',
#  'CHEMBL501235',
#  'CHEMBL4563408',
#  'CHEMBL4579120',
#  'CHEMBL4562303',
#  'CHEMBL4779424',
#  'CHEMBL1800685',
#  'CHEMBL5092058',
#  'CHEMBL5078078',
#  'CHEMBL5398630',
#  'CHEMBL3183055',
#  'CHEMBL2017291',
#  'CHEMBL3643413',
#  'CHEMBL5542124',
#  'CHEMBL3314012',
#  'CHEMBL4518483',
#  'CHEMBL128',
#  'CHEMBL292779',
#  'CHEMBL115249',
#  'CHEMBL116735',
#  'CHEMBL116463',
#  'CHEMBL326263',
#  'CHEMBL159483',
#  'CHEMBL160070',
#  'CHEMBL113956',
#  'CHEMBL117537',
#  'CHEMBL325516',
#  'CHEMBL420965',
#  'CHEMBL325258',
#  'CHEMBL161780',
#  'CHEMBL66227',
#  'CHEMBL313714',
#  'CHEMBL297446',
#  'CHEMBL179578',
#  'CHEMBL179234',
#  'CHEMBL184717',
#  'CHEMBL267615',
#  'CHEMBL194305',
#  'CHEMBL364005',
#  'CHEMBL194837',
#  'CHEMBL277120',
#  'CHEMBL54786',
#  'CHEMBL708',
#  'CHEMBL383530',
#  'CHEMBL375369',
#  'CHEMBL218206',
#  'CHEMBL219267',
#  'CHEMBL218343',
#  'CHEMBL374874',
#  'CHEMBL376753',
#  'CHEMBL221297',
#  'CHEMBL222320',
#  'CHEMBL373389',
#  'CHEMBL426712',
#  'CHEMBL436513',
#  'CHEMBL221250',
#  'CHEMBL219215',
#  'CHEMBL437147',
#  'CHEMBL218533',
#  'CHEMBL386613',
#  'CHEMBL386612',
#  'CHEMBL218479',
#  'CHEMBL374497',
#  'CHEMBL218336',
#  'CHEMBL221249',
#  'CHEMBL218589',
#  'CHEMBL221305',
#  'CHEMBL218587',
#  'CHEMBL373966',
#  'CHEMBL219265',
#  'CHEMBL218592',
#  'CHEMBL221387',
#  'CHEMBL250689',
#  'CHEMBL249854',
#  'CHEMBL259415',
#  'CHEMBL261102',
#  'CHEMBL261019',
#  'CHEMBL261434',
#  'CHEMBL259776',
#  'CHEMBL260907',
#  'CHEMBL259199',
#  'CHEMBL406221',
#  'CHEMBL493625',
#  'CHEMBL495250',
#  'CHEMBL495212',
#  'CHEMBL497749',
#  'CHEMBL495678',
#  'CHEMBL493816',
#  'CHEMBL427518',
#  'CHEMBL51',
#  'CHEMBL469149',
#  'CHEMBL51',
#  'CHEMBL516452',
#  'CHEMBL479952',
#  'CHEMBL519103',
#  'CHEMBL480699',
#  'CHEMBL480127',
#  'CHEMBL14460',
#  'CHEMBL472389',
#  'CHEMBL443922',
#  'CHEMBL257423',
#  'CHEMBL488060',
#  'CHEMBL488911',
#  'CHEMBL488912',
#  'CHEMBL451178',
#  'CHEMBL450714',
#  'CHEMBL487053',
#  'CHEMBL454288',
#  'CHEMBL488069',
#  'CHEMBL447733',
#  'CHEMBL488021',
#  'CHEMBL488241',
#  'CHEMBL488242',
#  'CHEMBL508192',
#  'CHEMBL488260',
#  'CHEMBL488261',
#  'CHEMBL488437',
#  'CHEMBL487223',
#  'CHEMBL487221',
#  'CHEMBL487222',
#  'CHEMBL529660',
#  'CHEMBL488434',
#  'CHEMBL444203',
#  'CHEMBL455511',
#  'CHEMBL451137',
#  'CHEMBL488435',
#  'CHEMBL487188',
#  'CHEMBL455423',
#  'CHEMBL451076',
#  'CHEMBL455424',
#  'CHEMBL455425',
#  'CHEMBL510435',
#  'CHEMBL455426',
#  'CHEMBL507884',
#  'CHEMBL455675',
#  'CHEMBL500329',
#  'CHEMBL448461',
#  'CHEMBL442923',
#  'CHEMBL453630',
#  'CHEMBL453631',
#  'CHEMBL454656',
#  'CHEMBL527094',
#  'CHEMBL454657',
#  'CHEMBL507075',
#  'CHEMBL472388',
#  'CHEMBL475121',
#  'CHEMBL447864',
#  'CHEMBL507721',
#  'CHEMBL449542',
#  'CHEMBL462387',
#  'CHEMBL461631',
#  'CHEMBL513629',
#  'CHEMBL462225',
#  'CHEMBL505091',
#  'CHEMBL462226',
#  'CHEMBL451330',
#  'CHEMBL452091',
#  'CHEMBL449048',
#  'CHEMBL455184',
#  'CHEMBL453879',
#  'CHEMBL453880',
#  'CHEMBL445754',
#  'CHEMBL584554',
#  'CHEMBL21343',
#  'CHEMBL576315',
#  'CHEMBL571858',
#  'CHEMBL584046',
#  'CHEMBL565745',
#  'CHEMBL565552',
#  'CHEMBL569475',
#  'CHEMBL593527',
#  'CHEMBL595133',
#  'CHEMBL606150',
#  'CHEMBL595457',
#  'CHEMBL605309',
#  'CHEMBL596148',
#  'CHEMBL603430',
#  'CHEMBL606144',
#  'CHEMBL595252',
#  'CHEMBL593614',
#  'CHEMBL603417',
#  'CHEMBL605089',
#  'CHEMBL593821',
#  'CHEMBL594519',
#  'CHEMBL604685',
#  'CHEMBL595449',
#  'CHEMBL594717',
#  'CHEMBL602882',
#  'CHEMBL602274',
#  'CHEMBL601659',
#  'CHEMBL605582',
#  'CHEMBL601872',
#  'CHEMBL600822',
#  'CHEMBL601022',
#  'CHEMBL605787',
#  'CHEMBL600012',
#  'CHEMBL600210',
#  'CHEMBL602087',
#  'CHEMBL602284',
#  'CHEMBL602285',
#  'CHEMBL601885',
#  'CHEMBL601886',
#  'CHEMBL601887',
#  'CHEMBL604952',
#  'CHEMBL601457',
#  'CHEMBL601458',
#  'CHEMBL601673',
#  'CHEMBL601037',
#  'CHEMBL601249',
#  'CHEMBL601250',
#  'CHEMBL601855',
#  'CHEMBL601859',
#  'CHEMBL602060',
#  'CHEMBL603272',
#  'CHEMBL601220',
#  'CHEMBL600606',
#  'CHEMBL600607',
#  'CHEMBL602677',
#  'CHEMBL602878',
#  'CHEMBL602889',
#  'CHEMBL603092',
#  'CHEMBL603499',
#  'CHEMBL603093',
#  'CHEMBL602279',
#  'CHEMBL1080215',
#  'CHEMBL1080726',
#  'CHEMBL1080727',
#  'CHEMBL1080728',
#  'CHEMBL1080745',
#  'CHEMBL1080746',
#  'CHEMBL1080747',
#  'CHEMBL1081302',
#  'CHEMBL1081303',
#  'CHEMBL1081468',
#  'CHEMBL1081644',
#  'CHEMBL1086613',
#  'CHEMBL1088163',
#  'CHEMBL1088164',
#  'CHEMBL1088165',
#  'CHEMBL1087773',
#  'CHEMBL1087895',
#  'CHEMBL1087896',
#  'CHEMBL1086626',
#  'CHEMBL1086754',
#  'CHEMBL1086755',
#  'CHEMBL1086756',
#  'CHEMBL1088312',
#  'CHEMBL1088313',
#  'CHEMBL1088314',
#  'CHEMBL1080671',
#  'CHEMBL1080672',
#  'CHEMBL1080522',
#  'CHEMBL1080683',
#  'CHEMBL1081035',
#  'CHEMBL1081036',
#  'CHEMBL1080711',
#  'CHEMBL1080712',
#  'CHEMBL1080554',
#  'CHEMBL1080555',
#  'CHEMBL1085155',
#  'CHEMBL1084617',
#  'CHEMBL1210154',
#  'CHEMBL1080726',
#  'CHEMBL1081644',
#  'CHEMBL1086754',
#  'CHEMBL1213856',
#  'CHEMBL1213931',
#  'CHEMBL1213932',
#  'CHEMBL1213933',
#  'CHEMBL1213934',
#  'CHEMBL1213985',
#  'CHEMBL3216707',
#  'CHEMBL1080728',
#  'CHEMBL1088163',
#  'CHEMBL1086756',
#  'CHEMBL1214045',
#  'CHEMBL1214046',
#  'CHEMBL1214047',
#  'CHEMBL1214113',
#  'CHEMBL1214114',
#  'CHEMBL1214115',
#  'CHEMBL1214116',
#  'CHEMBL1214175',
#  'CHEMBL1214176',
#  'CHEMBL1214177',
#  'CHEMBL1214178',
#  'CHEMBL1080522',
#  'CHEMBL2447969',
#  'CHEMBL1081035',
#  'CHEMBL1086626',
#  'CHEMBL1214302',
#  'CHEMBL1214303',
#  'CHEMBL1214304',
#  'CHEMBL1214305',
#  'CHEMBL1081468',
#  'CHEMBL1086613',
#  'CHEMBL1214366',
#  'CHEMBL1214367',
#  'CHEMBL1214425',
#  'CHEMBL1214426',
#  'CHEMBL1214427',
#  'CHEMBL1214428',
#  'CHEMBL1214488',
#  'CHEMBL1214489',
#  'CHEMBL3217141',
#  'CHEMBL3216259',
#  'CHEMBL3216702',
#  'CHEMBL1212957',
#  'CHEMBL1214546',
#  'CHEMBL1214547',
#  'CHEMBL1214594',
#  'CHEMBL1214595',
#  'CHEMBL1214596',
#  'CHEMBL1214597',
#  'CHEMBL1213673',
#  'CHEMBL1213674',
#  'CHEMBL1213675',
#  'CHEMBL1213676',
#  'CHEMBL1221452',
#  'CHEMBL1221449',
#  'CHEMBL1222134',
#  'CHEMBL1222234',
#  'CHEMBL1222138',
#  'CHEMBL1222364',
#  'CHEMBL1222363',
#  'CHEMBL1222362',
#  'CHEMBL1221497',
#  'CHEMBL1272092',
#  'CHEMBL1272041',
#  'CHEMBL1272040',
#  'CHEMBL1271985',
#  'CHEMBL1271984',
#  'CHEMBL1271930',
#  'CHEMBL1271929',
#  'CHEMBL1271874',
#  'CHEMBL1271873',
#  'CHEMBL1271816',
#  'CHEMBL1271815',
#  'CHEMBL1271757',
#  'CHEMBL1271756',
#  'CHEMBL1271698',
#  'CHEMBL1275709',
#  'CHEMBL1275791',
#  'CHEMBL1642116',
#  'CHEMBL1642117',
#  'CHEMBL1642118',
#  'CHEMBL1642123',
#  'CHEMBL1642126',
#  'CHEMBL1642128',
#  'CHEMBL51',
#  'CHEMBL3216738',
#  'CHEMBL3215630',
#  'CHEMBL3216083',
#  'CHEMBL3217176',
#  'CHEMBL3216508',
#  'CHEMBL3216085',
#  'CHEMBL3216745',
#  'CHEMBL3215631',
#  'CHEMBL3215853',
#  'CHEMBL3216746',
#  'CHEMBL3216961',
#  'CHEMBL3217169',
#  'CHEMBL3217170',
#  'CHEMBL3216501',
#  'CHEMBL3215850',
#  'CHEMBL3216962',
#  'CHEMBL3216081',
#  'CHEMBL3216286',
#  'CHEMBL3217171',
#  'CHEMBL3216287',
#  'CHEMBL3215628',
#  'CHEMBL3216740',
#  'CHEMBL3216963',
#  'CHEMBL3216964',
#  'CHEMBL3216291',
#  'CHEMBL3215629',
#  'CHEMBL3216503',
#  'CHEMBL3216741',
#  'CHEMBL3216742',
#  'CHEMBL3217173',
#  'CHEMBL3216498',
#  'CHEMBL3215618',
#  'CHEMBL3216078',
#  'CHEMBL3216959',
#  'CHEMBL3216737',
#  'CHEMBL3216093',
#  'CHEMBL3216298',
#  'CHEMBL3216754',
#  'CHEMBL3216974',
#  'CHEMBL3215862',
#  'CHEMBL3215863',
#  'CHEMBL3216517',
#  'CHEMBL3216094',
#  'CHEMBL3216755',
#  'CHEMBL3215864',
#  'CHEMBL3216975',
#  'CHEMBL3216518',
#  'CHEMBL3215638',
#  'CHEMBL3216299',
#  'CHEMBL3216756',
#  'CHEMBL3216095',
#  'CHEMBL3216757',
#  'CHEMBL3216521',
#  'CHEMBL3217181',
#  'CHEMBL3216744',
#  'CHEMBL3216505',
#  'CHEMBL3215852',
#  'CHEMBL3217175',
#  'CHEMBL3216965',
#  'CHEMBL3216506',
#  'CHEMBL3216293',
#  'CHEMBL3216966',
#  'CHEMBL3216967',
#  'CHEMBL3216507',
#  'CHEMBL3216084',
#  'CHEMBL3215627',
#  'CHEMBL3216082',
#  'CHEMBL3216288',
#  'CHEMBL3216289',
#  'CHEMBL3216290',
#  'CHEMBL3216285',
#  ...]

# %%
# Iterating canonical SMILES into a list
canonical_smiles = []
for i in df_assays.canonical_smiles:
    canonical_smiles.append(i)

# %%
# Iterating standard_value into a list
standard_value = []
for i in df_assays.standard_value:
    standard_value.append(i)

# %%
# Combining the four variables into the same DataFrame
dados_tupla = list(zip(mol_cid, canonical_smiles, classe_bioatividade, standard_value))
df3 = pd.DataFrame( dados_tupla,  columns=['molecule_chembl_id', 'canonical_smiles', 'classe_bioatividade', 'standard_value'])

# %%
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL26560                  CCCN1CC[C@H]2c3cccc(O)c3CC[C@H]21
# 1          CHEMBL148860  COc1cccc2c1O[C@@H](CN1[C@@H]3CC[C@H]1C[C@](O)(...
# 2          CHEMBL148860  COc1cccc2c1O[C@@H](CN1[C@@H]3CC[C@H]1C[C@](O)(...
# 3          CHEMBL151266  COc1cccc2c1O[C@@H](CN1[C@@H]3CC[C@H]1C[C@](O)(...
# 4          CHEMBL151266  COc1cccc2c1O[C@@H](CN1[C@@H]3CC[C@H]1C[C@](O)(...
# ...                 ...                                                ...
# 3573      CHEMBL5594692  COc1ccc2c3ccnc(C)c3n(CCN(C)C)c2c1.O=C(O)/C=C/C...
# 3574      CHEMBL5567330  COc1ccc2c(c1)N(CCN(C)C)/C(=C/C(C)=O)S2.O=C(O)/...
# 3575      CHEMBL1232461  CCNC(=O)C[C@@H]1N=C(c2ccc(Cl)cc2)c2cc(OC)ccc2-...
# 3576      CHEMBL2017291  COc1cc2c(cc1-c1c(C)noc1C)ncc1[nH]c(=O)n([C@H](...
# 3577        CHEMBL35226                CCCN1CCC(COc2nc3ccccc3c3c2CCCN3)CC1
#
#      classe_bioatividade standard_value
# 0               Inactive         1000.0
# 1               Inactive           36.0
# 2               Inactive          130.0
# 3               Inactive           25.0
# 4               Inactive           21.0
# ...                  ...            ...
# 3573            Inactive         2950.0
# 3574            Inactive         5530.0
# 3575            Inactive        40000.0
# 3576            Inactive        40000.0
# 3577            Inactive         3400.0
#
# [3578 rows x 4 columns]

# %%
# Saving the DataFrame to a CSV file

df3.to_csv('dados_preprocessados.csv', index=False)
